# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from sympy import Symbol
from sympy import init_printing
from sympy import integrate
from sympy import limit
from sympy import diff


# init_printing(use_unicode=False, wrap_line=False)

# x = Symbol('x')

# %%
def inf_function(x):
    return 25/x
x = np.linspace(-10,10,1000)
y = inf_function(x)
plt.plot(x,y)
plt.axvline(x = 0, color = "grey", linestyle= "--")
plt.axhline(y = 0, color = "grey", linestyle= "--")
plt.xlim(-10,10)
plt.ylim(-100,100)

plt.show()

# %%
x = Symbol("x")

# %%
limit(1/x,  x,0)
# Out:
# oo

# %%
limit(1/x,  x,"inf") # limit x tends to infinity which is 0
# Out:
# 1/inf

# %%
import math

# %%
limit((math.e)**x, x,-100000000000000000000000000000) 
# x tends to -inf , ans will be 0

#  e^-inf 
# = 1/e^inf 
# = 1/inf
# = 0
# Out:
# 1.08096667592447e-43429448190325179044577581883

# %%
def abs_function(x):
    return abs(x)
x = np.linspace(-10,10,1000)
y = abs_function(x)
plt.plot(x,y)
plt.axvline(x = 0, color = "grey", linestyle= "--")
plt.axhline(y = 0, color = "grey", linestyle= "--")

plt.ylim(-20,20)

plt.show()

# %%
def exp_function(x):
    import math
    return math.e**(x)
x = np.linspace(-10,10,1000)
y = exp_function(x)
plt.plot(x,y)
plt.axvline(x = 0, color = "grey", linestyle= "--")
plt.axhline(y = 0, color = "grey", linestyle= "--")

plt.ylim(-20,20)
plt.ylim(-100,100)


plt.show()

# %%
def log_function(x):
    
    return np.log(x)

x1 = np.linspace(-100,100,10000)

y = log_function(x1)
plt.plot(x1,y)


plt.axvline(x = 0, color = "grey", linestyle= "--")
plt.axhline(y = 0, color = "grey", linestyle= "--")




plt.show()

# %%
def sigmoid_function(x):
    
    return  1 / (1+(np.e)**(-x) )

x1 = np.linspace(-10,10,100)

y = sigmoid_function(x1)
plt.plot(x1,y)


plt.axvline(x = 0, color = "grey", linestyle= "--")
plt.axhline(y = 0, color = "grey", linestyle= "--")




plt.show()

# %% [markdown]
# differentiation  :
#
# what is the rate of change of y when we change x :

# %% [markdown]
#
# $$m = \frac{\text{change in }y}{\text{change in }x} = \frac{\Delta y}{\Delta x} = \frac{y_2 - y_1}{x_2 - x_1} $$

# %%
def f(x):
    return  x**2 
x = np.linspace(-10,10,1000)
y = f(x)

# %%
def f(x):
    return  x**2 
x = np.linspace(-10,10,1000)
y = f(x)

q = -5
p = 5
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(q,f(q))
plt.scatter(p,f(p))
plt.scatter(10,f(10))
plt.scatter(-10,f(-10))
plt.scatter(-7,f(-7))
plt.scatter(7,f(7))
plt.scatter(-2,f(-2))
plt.scatter(2,f(2))
plt.scatter(-1,f(-1))
plt.scatter(1,f(1))
plt.scatter(0,f(0))
plt.scatter(0,f(0))
  
ax.plot(x,y)

# %% [markdown]
# As $Q$ becomes infinitely close to $P$:
# * $x_2$ - $x_1$ approaches 0
# * In other words, $\Delta x$ approaches 0
# * This can be denoted as $\Delta x \to 0$
#
#
# Using the delta method, we've derived the definition of differentiation from first principles. The derivative of $y$ (denoted $dy$) with respect to $x$ (denoted $dx$) can be represented as:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{\Delta y}{\Delta x}$$
#
#
#
# Expanding $\Delta y$ out to $y_2 - y_1$:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{y_2 - y_1}{\Delta x}$$
#
#
#
# Finally, replacing $y_1$ with $f(x)$ and replacing $y_2$ with $f(x + \Delta x)$, we obtain a common representation of differentiation:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{f(x + \Delta x) - f(x)}{\Delta x}$$

# %% [markdown]
# ## Derivative :
#
# ### In mathematics, the derivative of a function of a real variable measures the sensitivity to change of the function value (output value) with respect to a change in its argument (input value).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://upload.wikimedia.org/wikipedia/commons/2/2d/Tangent_function_animation.gif

# %% [markdown]
# ## Elementary rules of differentiation

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://en.wikipedia.org/wiki/Derivative
#
# https://en.wikipedia.org/wiki/Trigonometric_functions

# %%
import sympy as sy

init_printing(use_unicode=False, wrap_line=False)
x = Symbol('x')

# %% [markdown]
# $$-\left(0.1x+10\right)^{2}\ +\ 5\left(x-50\right)\ +\ 785$$

# %%
((-(0.1*x+10)**2) + (5*(x-50)) + 785).diff(x)
# Out:
# 3.0 - 0.02*x

# %%
# d/dx [ ((x-9)**2) + (5*(x-50)) + 785) ]
 # =  2𝑥−13
    # 2x-13 = 0
    # x = 13/2
    
((((x-9)**2) + (5*(x-50)) + 785).diff(x))
# Out:
# 2*x - 13

# %%
((((x-9)**2) + (5*(x-50)) + 785).diff(x)).diff(x)
# Out:
# 2

# %%
((x+6)**2  + 20).diff(x)
# Out:
# 2*x + 12

# %% [markdown]
#     y = a - 4(x-b)^2
#
#     y' = f'(x) = d/dx  [a - 4(x-b)^2]
#
#                 = d/dx [a- 4(x^2 - 2xb + b^2) ]
#                 = d/dx [a - 4x^2 + 8xb - b^2 ]
#                 = 0 - 8x + 8b -0
#                 = -8x + 8b

# %%
a = 5
b = 8
(a-(4*(x-b)**2)).diff(x)
# Out:
# 64 - 8*x

# %%
-(8*x) + (8*b)
# Out:
# 64 - 8*x

# %% [markdown]
#     64 - 8x = 0
#     64 = 8x
#     x = 8
#     when x = b , y will be maximum
#
# ![image-2.png](attachment:image-2.png)

# %%
(3*x**2).diff(x)
# Out:
# 6*x

# %%
(x**4).diff(x)
# Out:
#    3
# 4*x

# %%
def f(x):
    return  x**2 


x = np.linspace(-10,10,100)

y = f(x)


diff_of_y = 2*x

fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
ax.plot(x,y)
ax.plot(x,diff_of_y)

# %%
def f(x):
    return  x**3  + 2*(x**2) + 3


x = np.linspace(-3,3,100)

y = f(x)


diff_of_y = 3*(x**2) + (4*x)

fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
ax.plot(x,y,label = "y")
ax.plot(x,diff_of_y,label = "diff_y")
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(x):
    return  -(x+6)**2  + 20


x = np.linspace(-20,10,100)

y = f(x)


diff_of_y = -2*x -12
dff_dff_y = -2 * np.ones(shape=x.size)

fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
ax.plot(x,y)
ax.plot(x,diff_of_y)
ax.plot(x,dff_dff_y)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(x):
    return  (x+6)**2  + 20


x = np.linspace(-20,10,100)

y = f(x)


diff_of_y = 2*x +12
dff_dff_y = 2 * np.ones(shape=x.size)

fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
ax.plot(x,y)
ax.plot(x,diff_of_y)
ax.plot(x,dff_dff_y)

# %% [markdown]
#     f''(x)>0 => minima
#     f''(x)<0 => maxima

# %% [markdown]
# ## y = $x^2$

# %%
x = np.arange(-10,10)
y = x**2
plt.plot(x,y)
dy_dx = 2*x
plt.plot(x,dy_dx)

# %%
x = np.arange(-10,10)
y = x**2
plt.plot(x,y)
dy_dx = y[1:]-y[:-1]
plt.plot(x[1:],dy_dx)

# %%
x = np.arange(-50,50)

# %%
y = x**3 + 2*(x**2) - 39

plt.plot(x,y)

# %%
pd.Series(y)
# Out:
# 0    -120039
# 1    -112886
# 2    -106023
# 3     -99444
# 4     -93143
#        ...
# 95     95136
# 96    101529
# 97    108202
# 98    115161
# 99    122412
# Length: 100, dtype: int32

# %%
x = np.arange(-50,50)

y = x**2

plt.plot(x,y)


plt.plot(x,pd.Series(y).diff())
plt.plot(x,pd.Series(y).diff().diff())

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.arange(-50,50)

y = ((x-9)**2) + (5*(x-50)) + 785

plt.plot(x,y)



plt.plot(x,pd.Series(y).diff())
plt.axvline(x = 13/2, color = "lightgrey")
plt.axhline(y = 573.75, color = "lightgrey")
plt.scatter(x = 13/2, y = 573.75)

# %%
(((13/2)-9)**2) + (5*((13/2)-50)) + 785
# Out:
# 573.75

# %%
 4 - 250 +785
# Out:
# 539

# %%
x = np.arange(-50,50)
def f(x):
    return ((x-2)**2) + (5*(x-50)) + 785
y = f(x)

plt.plot(x,y)

'''
df(x)/dx = d/dx (x^2 - 2x + 4 + 5x - 250 +785)
         = d/dx (x^2 +3x + 539)
         = 2x + 3 
         
at slope is  0 , df(x)/dx = 0

so  , 2x + 3 = 0
x = -3/2
'''




plt.plot(x,pd.Series(y).diff())
plt.axvline(x = -3/2, color = "lightgrey")
plt.axhline(y = f(-3/2), color = "lightgrey")
plt.scatter(x = -3/2, y = f(-3/2))

# %%
- 4  - 250 +785
# Out:
# 531

# %%
x = np.arange(-50,50)
def f(x):
    return (-(x-2)**2) + (5*(x-50)) + 785
y = f(x)

plt.plot(x,y)

'''


df(x)/dx = d/dx (-x^2 + 2x - 4 + 5x - 250 +785)
         = d/dx (-x^2 +7x + 531)
         = -2x + 7 
         
at slope is  0 , df(x)/dx = 0

so  , -2x + 7 = 0
x = 7/2



slope is negative : then its maxima 
if slope is positive then its minima 
we can also see, if double differentiation is +ve . then its minima
if double diff of a equation is -ve , then its maxima 


'''


plt.plot(x,pd.Series(y).diff())
plt.axvline(x = 7/2, color = "lightgrey")
plt.axhline(y = f(7/2), color = "lightgrey")
plt.scatter(x = 7/2, y = f(7/2))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.arange(-5000,5000)

def f(x):
    return ((-(0.1*x +10 )**2) + (5*(x-50)) + 785 )

y = f(x)
plt.plot(x,y)

'''
dy/dx = 3-0.02x

3-0.02x = 0
x = 3/0.02
x = 150


'''


plt.axvline(x = 150, color = "lightblue")
plt.axhline(y = f(150), color = "lightblue")
plt.scatter(x = 150, y = f(150))
plt.axhline(y = 0,color = "lightgrey")
plt.axvline(x = 0, color = "lightgrey")
plt.xlim(-1000,1500)
plt.ylim(-8000,3000)
# Out:
# (-8000.0, 3000.0)

# %%
3/0.02
# Out:
# 150.0
